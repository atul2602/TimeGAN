# %% [markdown]
# # Running TimeGAN
#
# - Epochs: 10,000
# - DataName: **stock**

# %% [markdown]
# ### PCA Plot
# ![image.png](attachment:image.png)

# %% [markdown]
# ### t-SNE Plot
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Metrics
#
# [t-SNE] Mean sigma: 0.037692
# [t-SNE] KL divergence after 250 iterations with early exaggeration: 54.656197
# [t-SNE] KL divergence after 300 iterations: 1.041549
# {'discriminative': 0.15252387448840382, 'predictive': 0.03771697478580955}
